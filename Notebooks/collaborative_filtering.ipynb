# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('Datasets/online_courses_updated.csv')
df = df.drop(columns=['Unnamed: 0'])

# %%
max_enrollments, min_enrollments = df['enrollment_numbers'].max(), df['enrollment_numbers'].min()
threshold_score = max_enrollments * 0.80
threshold_score
# Out:
# 39999.200000000004

# %%
df = df[df['enrollment_numbers']>threshold_score]
df.shape
# Out:
# (20041, 16)

# %%
df['course_name'].unique(), df['course_name'].nunique(), df['instructor'].unique(), df['instructor'].nunique()
# Out:
# (array(['Project Management Fundamentals',
#         'Networking and System Administration',
#         'Photography and Video Editing', 'Python for Beginners',
#         'Fitness and Nutrition Coaching', 'Graphic Design with Canva',
#         'Data Visualization with Tableau', 'Advanced Machine Learning',
#         'Stock Market and Trading Strategies',
#         'Cybersecurity for Professionals',
#         'DevOps and Continuous Deployment',
#         'Mobile App Development with Swift',
#         'Personal Finance and Wealth Building',
#         'Game Development with Unity', 'AI for Business Leaders',
#         'Ethical Hacking Masterclass', 'Cloud Computing Essentials',
#         'Public Speaking Mastery',
#         'Blockchain and Decentralized Applications',
#         'Fundamentals of Digital Marketing'], dtype=object),
#  20,
#  array(['Benjamin Lewis', 'Dr. Robert Davis', 'Daniel White',
#         'Charlotte King', 'Prof. Emily Johnson', 'James Clark',
#         'Olivia Taylor', 'Michael Brown', 'Jessica Martinez',
#         'Dr. John Smith', 'Liam Adams', 'William Thomas', 'Sarah Lee',
#         'Isabella Scott', 'Dr. Mia Walker', 'Ethan Hall',
#         'Sophia Anderson', 'Emma Harris', 'David Wilson',
#         'Alexander Young'], dtype=object),
#  20)

# %%
df['text_features'] = df['course_name'] + ' with ' + df['instructor']
df['text_features'] = df['text_features'].str.lower().str.strip()

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['text_features'])

# %%
collab_features = ['rating', 'course_price', 'feedback_score', 'time_spent_hours']
scaler = MinMaxScaler()
numeric_matrix = scaler.fit_transform(df[collab_features])

# %%
from scipy.sparse import hstack
combined_features = hstack([tfidf_matrix, numeric_matrix])
combined_features = combined_features.tocsr()

# %%
combined_features
# Out:
# <20041x104 sparse matrix of type '<class 'numpy.float64'>'
# 	with 182308 stored elements in Compressed Sparse Row format>

# %%
knn = NearestNeighbors(metric='cosine', algorithm='brute')
knn.fit(combined_features)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def recommend_courses(course_name, instructor, top_n=5):
    input_str = f"{course_name.strip()} with {instructor.strip()}".lower()
    ## match the course
    match = df[df['text_features'] == input_str]
    if match.empty:
        return "Course not found."

    idx = match.index[0]
    distances, indices = knn.kneighbors(combined_features[idx], n_neighbors=len(df))

    ## Flatten and remove self
    recommended_indices = indices.flatten()
    recommended_indices = recommended_indices[recommended_indices != idx]

    ## Build unique recommendations by course name + instructor
    seen = set()
    unique_recommendations = []
    for rec_idx in recommended_indices:
        row = df.iloc[rec_idx]
        key = (row['course_name'].strip().lower(), row['instructor'].strip().lower())
        if key != (course_name.strip().lower(), instructor.strip().lower()) and key not in seen:
            seen.add(key)
            unique_recommendations.append(row)
        if len(unique_recommendations) == top_n:
            break

    rec_df =  pd.DataFrame(unique_recommendations)[[
        'course_name','instructor','course_duration_hours','certification_offered','difficulty_level',	'rating','enrollment_numbers','course_price','feedback_score','study_material_available','time_spent_hours','previous_courses_taken','course_images','instructor_images'
    ]]
    return rec_df.sort_values(by='rating', ascending=False).head(top_n)

# %%
recommend_courses('Networking and System Administration', 'Dr. Mia Walker', top_n=5)
# Out:
#                              course_name       instructor  \
# 74677  Mobile App Development with Swift  Sophia Anderson
# 2446   Mobile App Development with Swift       Ethan Hall
# 86597  Mobile App Development with Swift   William Thomas
# 52147  Mobile App Development with Swift      Emma Harris
# 80825  Mobile App Development with Swift       Liam Adams
#
#        course_duration_hours certification_offered difficulty_level  rating  \
# 74677                    8.2                   Yes     Intermediate     4.0
# 2446                    81.9                   Yes         Advanced     3.8
# 86597                   14.0                   Yes         Beginner     3.6
# 52147                   46.3                   Yes         Beginner     3.6
# 80825                   53.9                    No         Advanced     3.0
#
#        enrollment_numbers  course_price  feedback_score  \
# 74677               44443        230.30           0.886
# 2446                40941        359.53           1.000
# 86597               41154        461.80           1.000
# 52147               41244        297.77           0.948
# 80825               47439        396.98           0.878
#
#       study_material_available  time_spent_hours  previous_courses_taken  \
# 74677                       No             28.89                       3
# 2446                       Yes             32.61                       2
# 86597                      Yes             47.39                       3
# 52147                      Yes             44.52                       4
# 80825                      Yes             48.30                       7
#
#                                            course_images  \
# 74677  https://images.unsplash.com/photo-163335612254...
# 2446   https://images.unsplash.com/photo-163335612254...
# 86597  https://images.unsplash.com/photo-163335612254...
# 52147  https://images.unsplash.com/photo-163335612254...
# 80825  https://images.unsplash.com/photo-163335612254...
#
#                                        instructor_images
# 74677  https://images.unsplash.com/photo-143876168103...
# 2446   https://images.pexels.com/photos/1043471/pexel...
# 86597  https://images.unsplash.com/photo-1557862921-3...
# 52147  https://images.pexels.com/photos/712521/pexels...
# 80825  https://images.pexels.com/photos/220453/pexels...

# %%
df.sample(5)
# Out:
#        user_id  course_id                           course_name  \
# 7346     29512       3673       Data Visualization with Tableau
# 70169     8650       4708  Personal Finance and Wealth Building
# 95827    36882       1478   Stock Market and Trading Strategies
# 28947     1512       9504         Photography and Video Editing
# 34922    19076       9655           Game Development with Unity
#
#              instructor  course_duration_hours certification_offered  \
# 7346     Dr. Mia Walker                   59.0                   Yes
# 70169        Ethan Hall                   93.3                    No
# 95827  Jessica Martinez                   96.8                   Yes
# 28947       James Clark                   85.5                   Yes
# 34922     Michael Brown                   52.6                   Yes
#
#       difficulty_level  rating  enrollment_numbers  course_price  \
# 7346          Beginner     4.6               47798        162.99
# 70169         Beginner     3.5               46346        215.48
# 95827         Beginner     3.6               43597        255.75
# 28947         Beginner     4.3               42433        236.09
# 34922         Advanced     3.8               47625        427.67
#
#        feedback_score study_material_available  time_spent_hours  \
# 7346            0.848                      Yes              1.00
# 70169           0.616                      Yes             26.24
# 95827           0.711                      Yes              1.00
# 28947           0.762                      Yes             17.84
# 34922           0.653                      Yes             31.58
#
#        previous_courses_taken  \
# 7346                        5
# 70169                       3
# 95827                       7
# 28947                       4
# 34922                       5
#
#                                            course_images  \
# 7346   https://images.pexels.com/photos/265087/pexels...
# 70169  https://images.unsplash.com/photo-1554224155-6...
# 95827  https://images.unsplash.com/photo-161197478985...
# 28947  https://images.unsplash.com/photo-151603506937...
# 34922  https://images.unsplash.com/photo-1542751371-a...
#
#                                        instructor_images  \
# 7346   https://images.pexels.com/photos/733872/pexels...
# 70169  https://images.pexels.com/photos/1043471/pexel...
# 95827  https://images.pexels.com/photos/1181686/pexel...
# 28947  https://images.pexels.com/photos/1222271/pexel...
# 34922  https://images.unsplash.com/photo-1560250097-0...
#
#                                            text_features
# 7346   data visualization with tableau with dr. mia w...
# 70169  personal finance and wealth building with etha...
# 95827  stock market and trading strategies with jessi...
# 28947     photography and video editing with james clark
# 34922     game development with unity with michael brown
