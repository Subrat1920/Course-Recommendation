# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datasets/online_courses_updated.csv')

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    user_id  course_id                       course_name       instructor  \
# 0    15796       9366              Python for Beginners      Emma Harris
# 1      861       1928   Cybersecurity for Professionals  Alexander Young
# 2    38159       9541  DevOps and Continuous Deployment   Dr. Mia Walker
# 3    44733       3708   Project Management Fundamentals   Benjamin Lewis
# 4    11285       3361       Ethical Hacking Masterclass     Daniel White
#
#    course_duration_hours certification_offered difficulty_level  rating  \
# 0                   39.1                   Yes         Beginner     5.0
# 1                   36.3                   Yes         Beginner     4.3
# 2                   13.4                   Yes         Beginner     3.9
# 3                   58.3                   Yes         Beginner     3.1
# 4                   30.8                   Yes         Beginner     2.8
#
#    enrollment_numbers  course_price  feedback_score study_material_available  \
# 0               21600        317.50           0.797                      Yes
# 1               15379         40.99           0.770                      Yes
# 2                6431        380.81           0.772                      Yes
# 3               48245        342.80           0.969                       No
# 4               34556        381.01           0.555                      Yes
#
#    time_spent_hours  previous_courses_taken  \
# 0             17.60                       4
# 1             28.97                       9
# 2             52.44                       4
# 3             22.29                       6
# 4             22.01                       5
#
#                                        course_images  \
# 0  https://images.unsplash.com/photo-152637909509...
# 1  https://images.pexels.com/photos/577585/pexels...
# 2  https://images.pexels.com/photos/270404/pexels...
# 3  https://images.unsplash.com/photo-157316471371...
# 4  https://images.unsplash.com/photo-156398676860...
#
#                                    instructor_images
# 0  https://images.pexels.com/photos/712521/pexels...
# 1  https://images.unsplash.com/photo-150064876779...
# 2  https://images.pexels.com/photos/733872/pexels...
# 3  https://images.unsplash.com/photo-151908536075...
# 4  https://images.pexels.com/photos/2379004/pexel...

# %%
df['enrollment_numbers'].max(), df['enrollment_numbers'].min()
# Out:
# (49999, 50)

# %%
top_courses_bought = df.groupby(['course_name', 'course_images'])['enrollment_numbers'].max().sort_values( ascending=False).reset_index()
top_courses_bought.head(15)
# Out:
#                                   course_name  \
# 0              Fitness and Nutrition Coaching
# 1        Personal Finance and Wealth Building
# 2           Mobile App Development with Swift
# 3           Fundamentals of Digital Marketing
# 4                     AI for Business Leaders
# 5                        Python for Beginners
# 6             Project Management Fundamentals
# 7               Photography and Video Editing
# 8         Stock Market and Trading Strategies
# 9                   Graphic Design with Canva
# 10       Networking and System Administration
# 11                    Public Speaking Mastery
# 12  Blockchain and Decentralized Applications
# 13                  Advanced Machine Learning
# 14           DevOps and Continuous Deployment
#
#                                         course_images  enrollment_numbers
# 0   https://images.unsplash.com/photo-157101961345...               49999
# 1   https://images.unsplash.com/photo-1554224155-6...               49999
# 2   https://images.unsplash.com/photo-163335612254...               49999
# 3   https://images.unsplash.com/photo-1551288049-b...               49999
# 4   https://images.pexels.com/photos/8438974/pexel...               49997
# 5   https://images.unsplash.com/photo-152637909509...               49997
# 6   https://images.unsplash.com/photo-157316471371...               49996
# 7   https://images.unsplash.com/photo-151603506937...               49995
# 8   https://images.unsplash.com/photo-161197478985...               49994
# 9   https://images.unsplash.com/photo-1547658719-d...               49991
# 10  https://images.unsplash.com/photo-157316471398...               49991
# 11  https://images.unsplash.com/photo-143154001516...               49991
# 12  https://images.pexels.com/photos/14902678/pexe...               49986
# 13  https://images.unsplash.com/photo-162071294354...               49984
# 14  https://images.pexels.com/photos/270404/pexels...               49982
